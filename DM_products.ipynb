# %%
import pandas as pd
import json
import requests
import time
from requests import get

# %%
df=pd.read_excel('products.xlsx',na_values='nope')

# %%
df.head()
# Out:
#        username       ip_address                       product   price  \
# 0      ldrover0  666.666.666.666            Clam - Cherrystone   712.8
# 1      kizakov1              NaN  Soup - Campbells Bean Medley  379.26
# 2      abromet2   240.177.79.234       Island Oasis - Lemonade  305.96
# 3  kkarolowski3    26.191.237.49      Water - Mineral, Natural  350.15
# 4     mbuckney4    58.90.204.239              Radish - Pickled  949.79
#
#                              infos
# 0                May contain sugar
# 1         Contains peanut and fish
# 2    Ingredients: mustard and fish
# 3                  Contains gluten
# 4  May contain sugar, egg and fish

# %%
df=df.dropna(axis=0,subset=['ip_address'])

# %%
df.head()
# Out:
#        username       ip_address                   product       price  \
# 0      ldrover0  666.666.666.666        Clam - Cherrystone       712.8
# 2      abromet2   240.177.79.234   Island Oasis - Lemonade      305.96
# 3  kkarolowski3    26.191.237.49  Water - Mineral, Natural      350.15
# 4     mbuckney4    58.90.204.239          Radish - Pickled      949.79
# 5   bsnozzwell5     226.52.32.70              Oil - Sesame  354.33 MGA
#
#                              infos
# 0                May contain sugar
# 2    Ingredients: mustard and fish
# 3                  Contains gluten
# 4  May contain sugar, egg and fish
# 5      Ingredients: sugar and milk

# %%
getprice = df["price"].str.split(" ",n = 1, expand = True) 
df.price = getprice[0]
df["currency"] = getprice[1]

# %%
df.head()
# Out:
#        username       ip_address                   product   price  \
# 0      ldrover0  666.666.666.666        Clam - Cherrystone   712.8
# 2      abromet2   240.177.79.234   Island Oasis - Lemonade  305.96
# 3  kkarolowski3    26.191.237.49  Water - Mineral, Natural  350.15
# 4     mbuckney4    58.90.204.239          Radish - Pickled  949.79
# 5   bsnozzwell5     226.52.32.70              Oil - Sesame  354.33
#
#                              infos currency
# 0                May contain sugar     None
# 2    Ingredients: mustard and fish     None
# 3                  Contains gluten     None
# 4  May contain sugar, egg and fish     None
# 5      Ingredients: sugar and milk      MGA

# %%
#ips=df['ip_address']

# %%
def Currency_IP(ip):
    api_url = 'http://free.ipwhois.io/json/'
    try:
        data=[]
        url = api_url + ip
        response = requests.get(url)
        time.sleep(1.0)
        data = json.loads(response.text)
        time.sleep(1.0)
        cur=(data['currency_code'])
        return cur
    except:
        return None

# %%
df.currency = df.ip_address.apply(Currency_IP)

# %%
df.head()
# Out:
#        username       ip_address                   product   price  \
# 0      ldrover0  666.666.666.666        Clam - Cherrystone   712.8
# 2      abromet2   240.177.79.234   Island Oasis - Lemonade  305.96
# 3  kkarolowski3    26.191.237.49  Water - Mineral, Natural  350.15
# 4     mbuckney4    58.90.204.239          Radish - Pickled  949.79
# 5   bsnozzwell5     226.52.32.70              Oil - Sesame  354.33
#
#                              infos currency
# 0                May contain sugar     None
# 2    Ingredients: mustard and fish      MYR
# 3                  Contains gluten      USD
# 4  May contain sugar, egg and fish      JPY
# 5      Ingredients: sugar and milk      MYR

# %%
df.dropna(subset=['currency'], inplace=True)

# %%
df.head()
# Out:
#        username       ip_address                   product   price  \
# 2      abromet2   240.177.79.234   Island Oasis - Lemonade  305.96
# 3  kkarolowski3    26.191.237.49  Water - Mineral, Natural  350.15
# 4     mbuckney4    58.90.204.239          Radish - Pickled  949.79
# 5   bsnozzwell5     226.52.32.70              Oil - Sesame  354.33
# 6   afairholme6  127.197.204.119      Chicken - Tenderloin  484.83
#
#                              infos currency
# 2    Ingredients: mustard and fish      MYR
# 3                  Contains gluten      USD
# 4  May contain sugar, egg and fish      JPY
# 5      Ingredients: sugar and milk      MYR
# 6                May contain sugar      JPY

# %%
url1="http://data.fixer.io/api/latest?access_key=581be85d2d399af866fb994f48f0911e&format=1"
fx = requests.get(url1).json()["rates"]
df.price = pd.to_numeric(df.price)
df.price = df.apply(lambda k: k['price'] / fx[k['currency']], axis=1)

# %%
df.head()
# Out:
#        username       ip_address                   product       price  \
# 2      abromet2   240.177.79.234   Island Oasis - Lemonade   65.554368
# 3  kkarolowski3    26.191.237.49  Water - Mineral, Natural  314.231741
# 4     mbuckney4    58.90.204.239          Radish - Pickled    7.853034
# 5   bsnozzwell5     226.52.32.70              Oil - Sesame   75.918026
# 6   afairholme6  127.197.204.119      Chicken - Tenderloin    4.008661
#
#                              infos currency
# 2    Ingredients: mustard and fish      MYR
# 3                  Contains gluten      USD
# 4  May contain sugar, egg and fish      JPY
# 5      Ingredients: sugar and milk      MYR
# 6                May contain sugar      JPY

# %%
contains = df.infos \
.str.lower()\
.str.replace('contains','')\
.str.replace('may','')\
.str.replace('contain','')\
.str.replace('and','')\
.str.replace('ingredient','')\
.str.replace(':','')\
.str.replace(',','')\
.str.replace(';','')\
.str.replace('.','')\
.str.replace('/','')\
.str.replace('(','')\
.str.replace(')','')\
.str.replace("ingredients",'')\
.str.split(" ")

# %%
dummies = pd.get_dummies(contains.explode())
dummies = dummies.groupby(dummies.index).sum()
dummies = dummies.drop(columns="s")
dummies=dummies.drop(dummies.columns[0], axis=1)
dummies = dummies.astype('bool')

# %%
dummies
# Out:
#        egg   fish  gluten   milk  mustard  peanut   soja  sugar
# 2    False   True   False  False     True   False  False  False
# 3    False  False    True  False    False   False  False  False
# 4     True   True   False  False    False   False  False   True
# 5    False  False   False   True    False   False  False   True
# 6    False  False   False  False    False   False  False   True
# ..     ...    ...     ...    ...      ...     ...    ...    ...
# 192  False  False   False  False    False   False  False   True
# 193   True   True   False  False    False   False  False   True
# 195  False   True    True   True     True   False  False   True
# 197  False  False    True  False    False   False   True  False
# 198  False  False   False  False    False   False   True   True
#
# [185 rows x 8 columns]

# %%
df = df.join(dummies)

# %%
df
# Out:
#            username       ip_address                       product  \
# 2          abromet2   240.177.79.234       Island Oasis - Lemonade
# 3      kkarolowski3    26.191.237.49      Water - Mineral, Natural
# 4         mbuckney4    58.90.204.239              Radish - Pickled
# 5       bsnozzwell5     226.52.32.70                  Oil - Sesame
# 6       afairholme6  127.197.204.119          Chicken - Tenderloin
# ..              ...              ...                           ...
# 192       ioxtoby5c     224.1.159.40    Brandy Cherry - Mcguinness
# 193     tliddyard5d     93.22.46.177    Shrimp - Black Tiger 6 - 8
# 195       ccannop5f     174.5.73.129        Nantucket Orange Juice
# 197  iollarenshaw5h    206.30.25.226         Juice - Apple, 341 Ml
# 198    mjablonski5i   44.133.211.182  Mushroom - Chantrelle, Fresh
#
#           price                                           infos currency  \
# 2     65.554368                   Ingredients: mustard and fish      MYR
# 3    314.231741                                 Contains gluten      USD
# 4      7.853034                 May contain sugar, egg and fish      JPY
# 5     75.918026                     Ingredients: sugar and milk      MYR
# 6      4.008661                               May contain sugar      JPY
# ..          ...                                             ...      ...
# 192  151.103289                              Ingredients: sugar      MYR
# 193  300.030000                Ingredients: sugar, egg and fish      EUR
# 195  489.403348  Contains gluten, mustard, sugar, milk and fish      CAD
# 197  401.299465                     May contain gluten and soja      USD
# 198  567.429923                     Ingredients: soja and sugar      USD
#
#        egg   fish  gluten   milk  mustard  peanut   soja  sugar
# 2    False   True   False  False     True   False  False  False
# 3    False  False    True  False    False   False  False  False
# 4     True   True   False  False    False   False  False   True
# 5    False  False   False   True    False   False  False   True
# 6    False  False   False  False    False   False  False   True
# ..     ...    ...     ...    ...      ...     ...    ...    ...
# 192  False  False   False  False    False   False  False   True
# 193   True   True   False  False    False   False  False   True
# 195  False   True    True   True     True   False  False   True
# 197  False  False    True  False    False   False   True  False
# 198  False  False   False  False    False   False   True   True
#
# [185 rows x 14 columns]
